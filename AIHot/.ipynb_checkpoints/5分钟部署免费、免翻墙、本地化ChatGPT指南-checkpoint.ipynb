# %% [markdown]
# ## 5分钟部署免费、免翻墙、本地化ChatGPT指南
# ### 让每个人都拥有自己的ChatGPT
#
# ## 部署步骤

# %% [markdown]
# ### 1、fork github
#
# fork https://github.com/Chanzhaoyu/chatgpt-web
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2、准备OPENAI_ACCESS_TOKEN&代理
# - OPENAI_ACCESS_TOKEN: 获取方式 https://chat.openai.com/api/auth/session
# - api_key(可选)：如果你想使用更稳定的方法，建议走API key
# - 社区代理：
#     - https://bypass.churchless.tech/api/conversatio
#     - https://api.pawan.krd/backend-api/conversation
#
# #### 2.1 api方案介绍
# ![image.png](attachment:image-2.png)
#
#
# ![image.png](attachment:image.png)
#
# OPENAI_ACCESS_TOKEN如图：
# OPENAI_ACCESS_TOKEN获取链接：https://chat.openai.com/api/auth/session
#
# ![image.png](attachment:image-3.png)

# %% [markdown]
# ### 3、部署自己的chatGPT
# 我们使用railway部署
#
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 4、生成访问域名
# ![image.png](attachment:image.png)
#
# 使用本地部署ChatGPT:
#
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ### 风险：
# - 采用OPENAI_ACCESS_TOKEN的方案，不太稳定，且有有效期限制
# - 采用API方案，稳定，但费用较高
#
# ## 免责声明：
# 此教程分享仅限自用、研究使用，拒绝商用。
