# %% [markdown]
# ## 前言
# - 官网地址：https://github.com/ExpressGit/Auto-GPT
#
# ### 目标
# - Auto-GPT是一个实验性开源应用程序，展示了 GPT-4 语言模型的功能。
# - 该程序由 GPT-4 驱动，将 LLM 的“思想”链接在一起，以自主实现你设定的任何目标。
# - 作为 GPT-4 完全自主运行的首批示例之一，Auto-GPT 突破了 AI 的可能性界限。
#
# ### 特性
# - 🌐 支持通过网络搜索收集信 息
# - 💾 支持长短期的内存管理（依赖redis）
# - 🧠 支持使用GPT-4实例用于文本生成
# - 🔗 支持访问常用的网站和平台
# - 🗃️ 支持使用GPT-3.5进行文件存储和摘要
# - 🗃️ 支持window&linux环境
#
# ### 项目依赖
# #### 1、环境(选择一个)
# - 建议：VSCode + dev container: It has been configured in the .devcontainer folder and can be used directly
# - 建议：Docker
# - Python 3.10 or later (instructions: for Windows)
#
# #### 2、OpenAI API key
#
# ### 可选依赖项Optional
# #### 1、Memory backend (pick one)
# - Pinecone(收费）
# - Milvus
# - Redis（建议）
# ##### 2、ElevenLabs Key (If you want the AI to speak) --收费

# %% [markdown]
# ## 安装
# ### 基础配置
# - 复制项目中.env.template文件，重命名为.env文件
# - 打开.env文件编辑环境变量
# - OPENAI_API_KEY 更新为你的api_key
# ![image.png](attachment:image.png)
# - 保存并关闭.env文件
#
# ### 进阶配置
# #### google api key
# - 打开 Google Cloud Console.https://console.cloud.google.com/ (需翻墙）
# - 如果没有账号则注册一个账号
# - 创建新项目（new project）
# - 进入（APIs & Services Dashboard ），并搜索“Custom Search API”,并“启用”API 服务
# - 创建凭据，生成API key
# ![image-2.png](attachment:image-2.png)
#
# #### CUSTOM_SEARCH_ENGINE_ID
# - 打开：https://programmablesearchengine.google.com/cse/all (需翻墙）
# - 新增搜索引擎
# - 填入搜索网站：*.google.com
# - 复制 custom_search_engine_id
# ![image-3.png](attachment:image-3.png)
#
# 将以上两个key更新至.env文件中

# %% [markdown]
# ### docker环境安装（windwos）
# vscode dev containers扩展：
#
# ![image-3.png](attachment:image-3.png)
#
# window docker desktop:
#
# - 下载安装链接：https://docs.docker.com/desktop/install/windows-install/
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### linux环境
# 安装 docker:
# - sudo yum install docker
# - sudo service docker start
# - sudo chkconfig docker on
#
# 安装 docker-compose:
#
# - 下载：curl -L https://get.daocloud.io/docker/compose/releases/download/1.29.1/docker-compose-`uname -s`-`uname -m` > /usr/local/bin/docker-compose
#
# > 下载路径是【/usr/local/bin/】下载完之后可以看下【/usr/local/bin】这个目录有没有【docker-compose】文件
#
# - docker-compose目录授权:sudo chmod +x /usr/local/bin/docker-compose
# - 测试：docker-compose version

# %% [markdown]
# ### 部署
# - git clone https://github.com/ExpressGit/Auto-GPT.git （建议，本工程部署代码已做加速优化）
# - cd Auto-GPT
# - 执行：docker-compose run --rm auto-gpt --gpt3only --continuous
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 运行
# 案例任务
# - task_1:Open the autogpt.net website
# - task_2:crawl the autogpt tab under the article
# - task_3:crawl the article title, time, author, article content
# - task_4:save it in a local file
# - task_5:show me the files

# %% [markdown]
# docker desktop:
# ![image.png](attachment:image.png)
#
# terminal：
# ![image-3.png](attachment:image-3.png)
