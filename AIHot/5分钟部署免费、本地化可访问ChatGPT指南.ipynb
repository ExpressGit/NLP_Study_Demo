# %% [markdown]
# ## 5分钟部署免费、本地化可访问ChatGPT指南
# ### 让每个人都拥有自己的ChatGPT
#
# ## 部署步骤

# %% [markdown]
# ### 1、fork github
#
# fork https://github.com/ExpressGit/ChatGPTWeb
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 2、准备OPENAI_ACCESS_TOKEN&代理
#
# - 进入 service/.env.example 文件，复制内容到 service/.env 文件
# - 使用 OpenAI API Key 请填写 OPENAI_API_KEY 字段 (获取 apiKey)
# - 使用 Web API 请填写 OPENAI_ACCESS_TOKEN 字段 (获取方式：具体详见RD)
# - 同时存在时以 OpenAI API Key 优先
#
#
# #### 2.1 api方案介绍
# ![image.png](attachment:image-2.png)
#
#
# OPENAI_ACCESS_TOKEN如图：
#
# OPENAI_ACCESS_TOKEN获取链接：
#
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### 3、部署自己的chatGPT
# 我们使用railway部署
#
# ![image-2.png](attachment:image-2.png)
#
# 准备环境变量：

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 4、生成访问域名
#
#
# ![image-4.png](attachment:image-4.png)
# 使用本地部署ChatGPT:
#
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ### 风险：
# - 采用OPENAI_ACCESS_TOKEN的方案，免费，但不太稳定，且有有效期限制
# - 采用OPENAI_API_KEY方案，稳定，但费用较高
#
# ## 免责声明：
# 此教程分享仅限自用、研究使用，拒绝商用。
